# %% [markdown]
# <a href="https://colab.research.google.com/github/vanyagoncharov/CourseMLResourse/blob/main/linear_reg_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import warnings
warnings.filterwarnings('ignore')

import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams, rcParamsDefault

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error


from sklearn.model_selection import train_test_split

import urllib

# %%
pd.set_option('display.max_columns', None)
pd.options.display.float_format = '{:.2f}'.format
pd.options.mode.chained_assignment = None

rcParams['figure.figsize'] = (8,8)
# %config InlineBackend.figure_format = 'svg'
# %matplotlib inline
factor = 1
default_dpi = rcParamsDefault['figure.dpi']
rcParams['figure.dpi'] = default_dpi*factor

# %%
# Напишем функцию линейной регрессии

def linear_model(x, a, b):
    """Linear model of the form y = a * x + b"""
    y = a * x + b
    return y

# %%
# загружаем данные
urllib.request.urlretrieve("https://raw.githubusercontent.com/CC-MNNIT/2018-19-Classes/master/MachineLearning/2018_08_22_Logical-Rhythm-2/data.csv", "data.csv")
data = np.genfromtxt('data.csv', delimiter=',')

# %%
# получаем значения x и y
x = np.array(data[:20,0])
y = np.array(data[:20,1])

# %%
# нарисуем dataset
plt.figure(figsize=(5,5))
plt.scatter(x,y)
plt.xlabel('Часы обучения студента')
plt.ylabel('Оценки по тестам у студента')
plt.show()

# %%
b = 1
a = -1

pred_y = linear_model(x, b, a)
pred_y
# Out:
# array([31.50234527, 52.42680403, 60.53035803, 46.47563963, 58.81320787,
#        54.14218841, 51.21179669, 38.29956669, 47.10504169, 51.55001444,
#        44.41973014, 53.35163488, 43.1640495 , 57.16847072, 55.72720806,
#        47.95588857, 43.68719623, 59.29732685, 44.61864377, 37.81681754])

# %%
# нарисуем dataset
plt.figure(figsize=(5,5))
plt.scatter(x,y)
plt.plot(x,pred_y, color='green')


plt.plot(np.vstack([x,x]), np.vstack([y, pred_y]), color="red");


plt.xlabel('Часы обучения студента')
plt.ylabel('Оценки по тестам у студента')
plt.show()

# %%
# посчитаем ошибку предсказания MAE

mean_absolute_error(y, pred_y).round(2), mean_squared_error(y, pred_y).round(2)
# Out:
# (20.47, 528.07)

# %%
model = LinearRegression()
model.fit(x[:,np.newaxis], y)
# Out:
# LinearRegression()

# %%
pred_y_m=model.predict(x[:, np.newaxis])

# %%
mean_absolute_error(y, pred_y_m).round(2), mean_squared_error(y, pred_y_m).round(2)
# Out:
# (7.88, 98.58)

# %%
(mean_squared_error(y, pred_y_m).round(2))**(1/2)
# Out:
# 9.92874614440313

# %%
# нарисуем dataset
plt.figure(figsize=(5,5))
plt.scatter(x,y)
plt.plot(x,pred_y_m, color='green')


plt.plot(np.vstack([x,x]), np.vstack([y, pred_y_m]), color="red");


plt.xlabel('Часы обучения студента')
plt.ylabel('Оценки по тестам у студента')
plt.show()

# %%
print(f'мы построили линейную регрессию y = {round(model.coef_[0],2)} + {round(model.intercept_, 2)}*x')
# Out:
# мы построили линейную регрессию y = 1.42 + -1.57*x
